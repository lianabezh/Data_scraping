# %%
import requests 
from scrapy.http import TextResponse
import time

# %%
response = requests.get("http://quotes.toscrape.com/")

# %%
response.url
# Out:
# 'http://quotes.toscrape.com/'

# %%
response.status_code
# Out:
# 200

# %%
print(response)
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n\t<meta charset="UTF-8">\n\t<title>Quotes to Scrape</title>\n    <link rel="stylesheet" href="/static/bootstrap.min.css">\n    <link rel="stylesheet" href="/static/main.css">\n</head>\n<body>\n    <div class="container">\n        <div class="row header-box">\n            <div class="col-md-8">\n                <h1>\n                    <a href="/" style="text-decoration: none">Quotes to Scrape</a>\n                </h1>\n            </div>\n            <div class="col-md-4">\n                <p>\n                \n                    <a href="/login">Login</a>\n                \n                </p>\n            </div>\n        </div>\n    \n\n<div class="row">\n    <div class="col-md-8">\n\n    <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">\n        <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>\n        <
# ...

# %%
type(page)
# Out:
# str

# %%
page.find("<small")
# Out:
# 972

# %%
print(page[972:1100])
# Out:
# <small class="author" itemprop="author">Albert Einstein</small>
#         <a href="/author/Albert-Einstein">(about)</a>
#         </

# %%
# !pip install scrapy
# Out:
# ...
#   Complete output from command D:\Users\USER\Anaconda3\python.exe -u -c "import setuptools, tokenize;__file__='C:\\Users\\USER\\AppData\\Local\\Temp\\pip-install-9mkn_w41\\Twisted\\setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d C:\Users\USER\AppData\Local\Temp\pip-wheel-vcnwa70o --python-tag cp37:
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.7
#   creating build\lib.win-amd64-3.7\twisted
#   copying src\twisted\copyright.py -> build\lib.win-amd64-3.7\twisted
#   copying src\twisted\plugin.py -> build\lib.win-amd64-3.7\twisted
#   copying src\twisted\_version.py -> build\lib.win-amd64-3.7\twisted
#   copying src\twisted\__init__.py -> build\lib.win-amd64-3.7\twisted
#   copying src\twisted\__main__.py -> build\lib.win-amd64-3.7\twisted
#   creating build\lib.win-amd64-3.7\twisted\application
# ...

# %%
page = TextResponse(url = response.url ,body = response.text , encoding = "utf-8")

# %%
page.css("small::text").extract()
# Out:
# ['Albert Einstein',
#  'J.K. Rowling',
#  'Albert Einstein',
#  'Jane Austen',
#  'Marilyn Monroe',
#  'Albert Einstein',
#  'André Gide',
#  'Thomas A. Edison',
#  'Eleanor Roosevelt',
#  'Steve Martin']

# %%
page.css("span[class='text']::text").extract()
# Out:
# ['“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”',
#  '“It is our choices, Harry, that show what we truly are, far more than our abilities.”',
#  '“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”',
#  '“The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”',
#  "“Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”",
#  '“Try not to become a man of success. Rather become a man of value.”',
#  '“It is better to be hated for what you are than to be loved for what you are not.”',
#  "“I have not failed. I've just found 10,000 ways that won't work.”",
#  "“A woman is like a tea bag; you never know how strong it is until it's in hot water.”",
#  '“A day without sunshine is like, you know, night.”']

# %%
page.css("a[class='tag']::text").extract()
# Out:
# ['change',
#  'deep-thoughts',
#  'thinking',
#  'world',
#  'abilities',
#  'choices',
#  'inspirational',
#  'life',
#  'live',
#  'miracle',
#  'miracles',
#  'aliteracy',
#  'books',
#  'classic',
#  'humor',
#  'be-yourself',
#  'inspirational',
#  'adulthood',
#  'success',
#  'value',
#  'life',
#  'love',
#  'edison',
#  'failure',
#  'inspirational',
#  'paraphrased',
#  'misattributed-eleanor-roosevelt',
#  'humor',
#  'obvious',
#  'simile',
#  'love',
#  'inspirational',
#  'life',
#  'humor',
#  'books',
#  'reading',
#  'friendship',
#  'friends',
#  'truth',
#  'simile']

# %%
page.css("a[class='tag']::attr(href)").extract()
# Out:
# ['/tag/change/page/1/',
#  '/tag/deep-thoughts/page/1/',
#  '/tag/thinking/page/1/',
#  '/tag/world/page/1/',
#  '/tag/abilities/page/1/',
#  '/tag/choices/page/1/',
#  '/tag/inspirational/page/1/',
#  '/tag/life/page/1/',
#  '/tag/live/page/1/',
#  '/tag/miracle/page/1/',
#  '/tag/miracles/page/1/',
#  '/tag/aliteracy/page/1/',
#  '/tag/books/page/1/',
#  '/tag/classic/page/1/',
#  '/tag/humor/page/1/',
#  '/tag/be-yourself/page/1/',
#  '/tag/inspirational/page/1/',
#  '/tag/adulthood/page/1/',
#  '/tag/success/page/1/',
#  '/tag/value/page/1/',
#  '/tag/life/page/1/',
#  '/tag/love/page/1/',
#  '/tag/edison/page/1/',
#  '/tag/failure/page/1/',
#  '/tag/inspirational/page/1/',
#  '/tag/paraphrased/page/1/',
#  '/tag/misattributed-eleanor-roosevelt/page/1/',
#  '/tag/humor/page/1/',
#  '/tag/obvious/page/1/',
#  '/tag/simile/page/1/',
#  '/tag/love/',
#  '/tag/inspirational/',
#  '/tag/life/',
#  '/tag/humor/',
#  '/tag/books/',
#  '/tag/reading/',
#  '/tag/friendship/',
# ...

# %%
"http://quotes.toscrape.com/page/3/"
# Out:
# 'http://quotes.toscrape.com/page/3/'

# %%
for i in range (1,11) :
    print("http://quotes.toscrape.com/page/" + str(i) +"/")
# Out:
# http://quotes.toscrape.com/page/1/
# http://quotes.toscrape.com/page/2/
# http://quotes.toscrape.com/page/3/
# http://quotes.toscrape.com/page/4/
# http://quotes.toscrape.com/page/5/
# http://quotes.toscrape.com/page/6/
# http://quotes.toscrape.com/page/7/
# http://quotes.toscrape.com/page/8/
# http://quotes.toscrape.com/page/9/
# http://quotes.toscrape.com/page/10/

# %%
["http://quotes.toscrape.com/page/" + str(i) +"/"for i in range(1,11)]
# Out:
# ['http://quotes.toscrape.com/page/1/',
#  'http://quotes.toscrape.com/page/2/',
#  'http://quotes.toscrape.com/page/3/',
#  'http://quotes.toscrape.com/page/4/',
#  'http://quotes.toscrape.com/page/5/',
#  'http://quotes.toscrape.com/page/6/',
#  'http://quotes.toscrape.com/page/7/',
#  'http://quotes.toscrape.com/page/8/',
#  'http://quotes.toscrape.com/page/9/',
#  'http://quotes.toscrape.com/page/10/']

# %%
["http://quotes.toscrape.com/page/{}/".format(i) for i in range(1,11)]
# Out:
# ['http://quotes.toscrape.com/page/1/',
#  'http://quotes.toscrape.com/page/2/',
#  'http://quotes.toscrape.com/page/3/',
#  'http://quotes.toscrape.com/page/4/',
#  'http://quotes.toscrape.com/page/5/',
#  'http://quotes.toscrape.com/page/6/',
#  'http://quotes.toscrape.com/page/7/',
#  'http://quotes.toscrape.com/page/8/',
#  'http://quotes.toscrape.com/page/9/',
#  'http://quotes.toscrape.com/page/10/']

# %%
"ybxk{}uyvs".format("LL")
# Out:
# 'ybxkLLuyvs'

# %%
def author_scraper(url):
    response = requests.get(url)
    page = TextResponse(url=response.url, body = response.text, encoding="utf-8")
    authors = page.css("small::text").extract()
    return authors

# %%
author_scraper("http://quotes.toscrape.com/page/1/")
# Out:
# ['Albert Einstein',
#  'J.K. Rowling',
#  'Albert Einstein',
#  'Jane Austen',
#  'Marilyn Monroe',
#  'Albert Einstein',
#  'André Gide',
#  'Thomas A. Edison',
#  'Eleanor Roosevelt',
#  'Steve Martin']

# %%
all_authors = []
for i in all_urls:
    all_authors.append(author_scraper(i)) 
    time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-760020ff4041> in <module>
#       2 for i in all_urls:
#       3     all_authors.append(author_scraper(i))
# ----> 4     time.sleep(2)
#
# NameError: name 'time' is not defined

# %%
print(all_authors)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-52079ea171e0> in <module>
# ----> 1 print(all_authors)
#
# NameError: name 'all_authors' is not defined

# %%
all_urls = ["http://quotes.toscrape.com/page/{}/".format(i) for i in range(1,11)]

# %%
all_authors = []
for i in all_urls:
    all_authors.append(author_scraper(i)) 
    time.sleep(2)

# %%
print(all_authors)
# Out:
# [['Albert Einstein', 'J.K. Rowling', 'Albert Einstein', 'Jane Austen', 'Marilyn Monroe', 'Albert Einstein', 'André Gide', 'Thomas A. Edison', 'Eleanor Roosevelt', 'Steve Martin'], ['Marilyn Monroe', 'J.K. Rowling', 'Albert Einstein', 'Bob Marley', 'Dr. Seuss', 'Douglas Adams', 'Elie Wiesel', 'Friedrich Nietzsche', 'Mark Twain', 'Allen Saunders'], ['Pablo Neruda', 'Ralph Waldo Emerson', 'Mother Teresa', 'Garrison Keillor', 'Jim Henson', 'Dr. Seuss', 'Albert Einstein', 'J.K. Rowling', 'Albert Einstein', 'Bob Marley'], ['Dr. Seuss', 'J.K. Rowling', 'Bob Marley', 'Mother Teresa', 'J.K. Rowling', 'Charles M. Schulz', 'William Nicholson', 'Albert Einstein', 'Jorge Luis Borges', 'George Eliot'], ['George R.R. Martin', 'C.S. Lewis', 'Marilyn Monroe', 'Marilyn Monroe', 'Albert Einstein', 'Marilyn Monroe', 'Marilyn Monroe', 'Martin Luther King Jr.', 'J.K. Rowling', 'James Baldwin'], ['Jane Austen', 'Eleanor Roosevelt', 'Marilyn Monroe', 'Albert Einstein', 'Haruki Murakami', 'Alexandre Dumas fi
# ...

# %%
all_authors = []
for i in all_urls:
    all_authors.extend(author_scraper(i)) 
    time.sleep(2)

# %%
print(all_authors)
# Out:
# ['Albert Einstein', 'J.K. Rowling', 'Albert Einstein', 'Jane Austen', 'Marilyn Monroe', 'Albert Einstein', 'André Gide', 'Thomas A. Edison', 'Eleanor Roosevelt', 'Steve Martin', 'Marilyn Monroe', 'J.K. Rowling', 'Albert Einstein', 'Bob Marley', 'Dr. Seuss', 'Douglas Adams', 'Elie Wiesel', 'Friedrich Nietzsche', 'Mark Twain', 'Allen Saunders', 'Pablo Neruda', 'Ralph Waldo Emerson', 'Mother Teresa', 'Garrison Keillor', 'Jim Henson', 'Dr. Seuss', 'Albert Einstein', 'J.K. Rowling', 'Albert Einstein', 'Bob Marley', 'Dr. Seuss', 'J.K. Rowling', 'Bob Marley', 'Mother Teresa', 'J.K. Rowling', 'Charles M. Schulz', 'William Nicholson', 'Albert Einstein', 'Jorge Luis Borges', 'George Eliot', 'George R.R. Martin', 'C.S. Lewis', 'Marilyn Monroe', 'Marilyn Monroe', 'Albert Einstein', 'Marilyn Monroe', 'Marilyn Monroe', 'Martin Luther King Jr.', 'J.K. Rowling', 'James Baldwin', 'Jane Austen', 'Eleanor Roosevelt', 'Marilyn Monroe', 'Albert Einstein', 'Haruki Murakami', 'Alexandre Dumas fils', 'Steph
# ...

# %%
all_authors = set(all_authors)

# %%
print(all_authors)
# Out:
# {'Elie Wiesel', 'C.S. Lewis', 'Garrison Keillor', 'Eleanor Roosevelt', 'George Carlin', 'Alexandre Dumas fils', 'Suzanne Collins', 'Stephenie Meyer', 'George Eliot', 'Pablo Neruda', 'Ralph Waldo Emerson', 'Alfred Tennyson', 'Jimi Hendrix', 'Terry Pratchett', 'John Lennon', 'Mark Twain', 'George Bernard Shaw', 'J.D. Salinger', 'Jorge Luis Borges', 'George R.R. Martin', 'Albert Einstein', 'Charles M. Schulz', 'J.M. Barrie', 'W.C. Fields', 'E.E. Cummings', 'Douglas Adams', "Madeleine L'Engle", 'Mother Teresa', 'Marilyn Monroe', 'Helen Keller', 'Khaled Hosseini', 'André Gide', 'Ernest Hemingway', 'Jim Henson', 'James Baldwin', 'Ayn Rand', 'J.K. Rowling', 'Harper Lee', 'Jane Austen', 'Charles Bukowski', 'Haruki Murakami', 'Steve Martin', 'Bob Marley', 'Martin Luther King Jr.', 'J.R.R. Tolkien', 'Thomas A. Edison', 'Dr. Seuss', 'Allen Saunders', 'Friedrich Nietzsche', 'William Nicholson'}

# %%
def q_scraper(url):
    response = requests.get(url)
    page = TextResponse(url=response.url, body = response.text, encoding="utf-8")
    quotes = page.css("span[class='text']::text").extract()
    return quotes

# %%
q_scraper("http://quotes.toscrape.com/page/1/")
# Out:
# ['“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”',
#  '“It is our choices, Harry, that show what we truly are, far more than our abilities.”',
#  '“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”',
#  '“The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”',
#  "“Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”",
#  '“Try not to become a man of success. Rather become a man of value.”',
#  '“It is better to be hated for what you are than to be loved for what you are not.”',
#  "“I have not failed. I've just found 10,000 ways that won't work.”",
#  "“A woman is like a tea bag; you never know how strong it is until it's in hot water.”",
#  '“A day without sunshine is like, you know, night.”']

# %%
quotes = []
for i in all_urls:
    quotes.extend(q_scraper(i)) 
    time.sleep(2)

# %%
print(quotes)
# Out:
# ['“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”', '“It is our choices, Harry, that show what we truly are, far more than our abilities.”', '“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”', '“The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”', "“Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”", '“Try not to become a man of success. Rather become a man of value.”', '“It is better to be hated for what you are than to be loved for what you are not.”', "“I have not failed. I've just found 10,000 ways that won't work.”", "“A woman is like a tea bag; you never know how strong it is until it's in hot water.”", '“A day without sunshine is like, you know, night.”', "“This life is what you make it. No matter what, you're going 
# ...

# %%
quotes = set (quotes)

# %%
print(quotes)
# Out:
# {'“If I had a flower for every time I thought of you...I could walk through my garden forever.”', "“′Classic′ - a book which people praise and don't read.”", "“If you can't explain it to a six year old, you don't understand it yourself.”", '“Only in the darkness can you see the stars.”', "“You may not be her first, her last, or her only. She loved before she may love again. But if she loves you now, what else matters? She's not perfect—you aren't either, and the two of you may never be perfect together but if she can make you laugh, cause you to think twice, and admit to being human and making mistakes, hold onto her and give her the most you can. She may not be thinking about you every second of the day, but she will give you a part of her that she knows you can break—her heart. So don't hurt her, don't change her, don't analyze and don't expect more than she can give. Smile when she makes you happy, let her know when she makes you mad, and miss her when she's not there.”", '“Anyone
# ...

# %%
quotes = []
i = 0 
while i<10: 
    quotes.extend(q_scraper(all_urls[i]))
    i = i+1
    time.sleep(2)

# %%
print(quotes)
# Out:
# ['“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”', '“It is our choices, Harry, that show what we truly are, far more than our abilities.”', '“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”', '“The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”', "“Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”", '“Try not to become a man of success. Rather become a man of value.”', '“It is better to be hated for what you are than to be loved for what you are not.”', "“I have not failed. I've just found 10,000 ways that won't work.”", "“A woman is like a tea bag; you never know how strong it is until it's in hot water.”", '“A day without sunshine is like, you know, night.”', "“This life is what you make it. No matter what, you're going 
# ...

# %%
len(quotes)
# Out:
# 100
